# %% [markdown]
# <a href="https://colab.research.google.com/github/arkobera/Research-SIH/blob/main/DashboardModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install meteostat

# %%
from meteostat import Point, Daily
from datetime import datetime
import pandas as pd

# Define location (Delhi) and time range
delhi = Point(28.6139, 77.2090)
start = datetime(2020, 1, 1)
end = datetime(2024, 6, 30)

# Fetch the daily weather data
data = Daily(delhi, start, end)
df = data.fetch()

# Display the data
print(df.head())

# You can save it to a CSV file if needed
#df.to_csv('delhi_weather_data.csv')
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2020-01-01  10.8   2.4  20.2   NaN   NaN    NaN   2.3   NaN  1021.9   NaN
# 2020-01-02  13.7   4.6  22.0   NaN   NaN   21.0   2.6   NaN  1021.6   NaN
# 2020-01-03  14.4   7.6  23.0   NaN   NaN   31.0   1.9   NaN  1019.2   NaN
# 2020-01-04  13.6   8.0  23.5   NaN   NaN  325.0   3.1   NaN  1017.9   NaN
# 2020-01-05  14.2   7.0  21.6   NaN   NaN  316.0   4.4   NaN  1018.3   NaN

# %%
df.resample("M").max()
# Out:
#             tavg  tmin  tmax   prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2020-01-31  16.0  11.9  23.5   10.9   NaN  325.0  12.6   NaN  1021.9   NaN
# 2020-02-29  21.8  16.7  27.8    2.0   NaN  329.0  14.8   NaN  1021.9   NaN
# 2020-03-31  25.6  19.4  33.3   99.1   NaN  331.0  12.0   NaN  1016.8   NaN
# 2020-04-30  31.2  25.7  40.1   20.1   NaN  344.0  12.1   NaN  1011.9   NaN
# 2020-05-31  38.6  28.7  46.0   11.9   NaN  348.0  14.8   NaN  1007.8   NaN
# 2020-06-30  37.1  30.3  42.5   43.9   NaN  347.0  11.8   NaN  1006.7   NaN
# 2020-07-31  36.2  30.4  41.6   70.1   NaN  306.0  11.6   NaN  1004.9   NaN
# 2020-08-31  33.9  29.0  37.6   68.1   NaN  330.0  13.7   NaN  1003.8   NaN
# 2020-09-30  34.3  28.0  38.0   19.1   NaN  350.0   8.1   NaN  1006.9   NaN
# 2020-10-31  30.5  23.7  37.0    0.0   NaN  355.0   6.6   NaN  1013.5   NaN
# 2020-11-30  22.1  16.0  31.6    2.0   NaN  355.0   6.2   NaN  1020.6   NaN
# ...

# %%
power_df = pd.read_json("/content/powerSupplyPos.json")
power_df.head()
# Out:
#    ID     Month                     State  energy_requirement  \
# 0  44  Jan-2020                Chandigarh              137.98
# 1  45  Jan-2020                     Delhi             2290.02
# 2  46  Jan-2020                   Haryana             3862.87
# 3  47  Jan-2020          Himachal Pradesh              931.24
# 4  48  Jan-2020   \nUTs of J&K and Ladakh             1934.00
#
#    energy_availability         fy
# 0               137.98  2019-2020
# 1              2290.02  2019-2020
# 2              3862.87  2019-2020
# 3               930.64  2019-2020
# 4              1699.59  2019-2020

# %%
power_df['Month'] = pd.to_datetime(power_df['Month'],format="%b-%Y")
power_df.head()
# Out:
#    ID      Month                     State  energy_requirement  \
# 0  44 2020-01-01                Chandigarh              137.98
# 1  45 2020-01-01                     Delhi             2290.02
# 2  46 2020-01-01                   Haryana             3862.87
# 3  47 2020-01-01          Himachal Pradesh              931.24
# 4  48 2020-01-01   \nUTs of J&K and Ladakh             1934.00
#
#    energy_availability         fy
# 0               137.98  2019-2020
# 1              2290.02  2019-2020
# 2              3862.87  2019-2020
# 3               930.64  2019-2020
# 4              1699.59  2019-2020

# %%
deficit_region = power_df.query('energy_requirement>energy_availability').sort_values(by='energy_requirement',ascending=False)
deficit_region.head()
# Out:
#          ID      Month       State  energy_requirement  energy_availability  \
# 2737  13179 2024-05-01   All India       155346.250593        155157.068329
# 2779  13221 2024-06-01   All India       152649.918127        152373.952956
# 2317   6963 2023-08-01   All India       152175.854330        151324.113405
# 2695  13095 2024-04-01   All India       144402.501973        144279.602565
# 2271   4875 2023-07-01   All India       144289.073778        144090.454367
#
#              fy
# 2737  2024-2025
# 2779  2024-2025
# 2317  2023-2024
# 2695  2024-2025
# 2271  2023-2024

# %%
delhi_deficit = power_df[power_df['State']==' Delhi']
#delhi_deficit['Diff'] = delhi_deficit['energy_requirement'] - delhi_deficit['energy_availability']
print(delhi_deficit.shape)
delhi_deficit.head(10)
# Out:
# (65, 6)
#        ID      Month   State  energy_requirement  energy_availability  \
# 1      45 2020-01-01   Delhi             2290.02              2290.02
# 44   1699 2020-01-01   Delhi             2290.02              2290.02
# 87   2736 2020-01-01   Delhi             2290.02              2290.02
# 130     2 2020-02-01   Delhi             1904.80              1904.53
# 173  1656 2020-02-01   Delhi             1904.80              1904.53
# 217  1613 2020-03-01   Delhi             1693.11              1692.62
# 260  1570 2020-04-01   Delhi             1670.53              1670.36
# 303  1527 2020-05-01   Delhi             2522.68              2522.68
# 346  1484 2020-06-01   Delhi             3110.12              3109.18
# 389  1441 2020-07-01   Delhi             3313.81              3313.23
#
#             fy
# 1    2019-2020
# 44   2019-2020
# 87   2019-2020
# 130  2019-2020
# 173  2019-2020
# 217  2019-2020
# 260  2020-2021
# 303  2020-2021
# 346  2020-2021
# 389  2020-2021

# %%
delhi = delhi_deficit.groupby('Month').agg({'energy_requirement':'sum','energy_availability':'sum'})
delhi['Diff'] = delhi['energy_requirement'] - delhi['energy_availability']
delhi.head()
# Out:
#             energy_requirement  energy_availability  Diff
# Month
# 2020-01-01             6870.06              6870.06  0.00
# 2020-02-01             3809.60              3809.06  0.54
# 2020-03-01             1693.11              1692.62  0.49
# 2020-04-01             1670.53              1670.36  0.17
# 2020-05-01             2522.68              2522.68  0.00

# %%
delhi = delhi.join(df['tmax'])
delhi
# Out:
#                      energy_requirement  energy_availability       Diff  tmax
# Month
# 2020-01-01 00:00:00         6870.060000          6870.060000   0.000000   NaN
# 2020-02-01 00:00:00         3809.600000          3809.060000   0.540000   NaN
# 2020-03-01 00:00:00         1693.110000          1692.620000   0.490000   NaN
# 2020-04-01 00:00:00         1670.530000          1670.360000   0.170000   NaN
# 2020-05-01 00:00:00         2522.680000          2522.680000   0.000000   NaN
# 2020-06-01 00:00:00         3110.120000          3109.180000   0.940000   NaN
# 2020-07-01 00:00:00         3313.810000          3313.230000   0.580000   NaN
# 2020-08-01 00:00:00         3166.450000          3165.910000   0.540000   NaN
# 2020-09-01 00:00:00         3342.840000          3342.540000   0.300000   NaN
# 2020-10-01 00:00:00         2451.117000          2450.916000   0.201000   NaN
# 2020-11-01 00:00:00         1784.455241          1784.360841   0.094400   NaN
# ...

# %%
delhi.shape
# Out:
# (54, 4)

# %%
delhi.plot(subplots=True)
# Out:
# array([<Axes: xlabel='Month'>, <Axes: xlabel='Month'>,
#        <Axes: xlabel='Month'>, <Axes: xlabel='Month'>], dtype=object)

# %%
delhi.head()
# Out:
#                      energy_requirement  energy_availability  Diff  tmax
# Month
# 2020-01-01 00:00:00             6870.06              6870.06  0.00   NaN
# 2020-02-01 00:00:00             3809.60              3809.06  0.54   NaN
# 2020-03-01 00:00:00             1693.11              1692.62  0.49   NaN
# 2020-04-01 00:00:00             1670.53              1670.36  0.17   NaN
# 2020-05-01 00:00:00             2522.68              2522.68  0.00   NaN

# %%
df = pd.read_csv("/content/delhi.csv")
df.head()
# Out:
#         Month  energy_requirement  energy_availability  Diff  tmax
# 0  2020-01-01             6870.06              6870.06  0.00  20.2
# 1  2020-02-01             3809.60              3809.06  0.54  19.7
# 2  2020-03-01             1693.11              1692.62  0.49  27.6
# 3  2020-04-01             1670.53              1670.36  0.17  32.6
# 4  2020-05-01             2522.68              2522.68  0.00  38.8

# %%
import pandas as pd

# Define holidays
holidays = pd.DataFrame({
    'holiday': ['Anamoly'],
    'ds': ['2022-06-01']
})

# Convert 'ds' to datetime format
holidays['ds'] = pd.to_datetime(holidays['ds'])

# %%
import pandas as pd
from prophet import Prophet

# Assuming 'delhi' is your DataFrame
# Reset the index to bring 'Month' as a column
#delhi = delhi.reset_index()

# Prepare data for Prophet
df.rename(columns={'Month': 'ds', 'energy_requirement': 'y'}, inplace=True)

# Initialize Prophet model
model = Prophet(holidays=holidays)

# Add 'tavg' as an additional regressor
model.add_regressor('tmax')

# Fit the model
model.fit(df[['ds', 'y', 'tmax']])

# Make future predictions (you can create a dataframe with future dates)
future = model.make_future_dataframe(periods=12, freq='MS')  # MS for month start

# Ensure you have 'tavg' values for all future dates in the 'future' dataframe
# If you don't have future 'tavg' values, consider using a different method to fill them,
# such as using historical averages or another forecasting model.
# Here's an example of filling with historical averages:
# Convert 'ds' column in both DataFrames to datetime
future['ds'] = pd.to_datetime(future['ds'])
df['ds'] = pd.to_datetime(df['ds'])

future = future.merge(df[['ds', 'tmax']], on='ds', how='left')
future['tmax'].fillna(df['tmax'].mean(), inplace=True)

# Predict
forecast = model.predict(future)

# Show the forecast
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']])
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphr1qdg3v/ogmse3y0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphr1qdg3v/iwa1z2hq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19319', 'data', 'file=/tmp/tmphr1qdg3v/ogmse3y0.json', 'init=/tmp/tmphr1qdg3v/iwa1z2hq.json', 'output', 'file=/tmp/tmphr1qdg3v/prophet_modelx42gyj7_/prophet_model-20240907081110.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 08:11:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:11:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# ...

# %%
import matplotlib.pyplot as plt

# Plotting the forecast with matplotlib
plt.figure(figsize=(10, 6))

# Plot the forecasted values
plt.plot(forecast['ds'], forecast['yhat'], label='Forecasted Energy Requirement')

# Plot the lower and upper bounds for the forecast
plt.fill_between(forecast['ds'], forecast['yhat_lower'], forecast['yhat_upper'], color='gray', alpha=0.3, label='Confidence Interval')

# Add titles and labels
plt.title('Energy Requirement Forecast')
plt.xlabel('Date')
plt.ylabel('Energy Requirement')
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting the actual vs predicted with confidence interval using matplotlib
plt.figure(figsize=(10, 6))

# Plot actual values
plt.plot(df['ds'], df['y'], label='Actual Energy Requirement', color='blue')

# Plot predicted values
plt.plot(forecast['ds'], forecast['yhat'], label='Predicted Energy Requirement', color='orange')

# Plot the lower and upper bounds for the forecast
plt.fill_between(forecast['ds'], forecast['yhat_lower'], forecast['yhat_upper'], color='gray', alpha=0.3, label='Confidence Interval')

# Add titles and labels
plt.title('Energy Requirement: Actual vs Predicted')
plt.xlabel('Date')
plt.ylabel('Energy Requirement')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# **Peak Power**

# %%
import pandas as pd

# %%
peak_df = pd.read_json("/content/peak.json")
peak_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2639 entries, 0 to 2638
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           2639 non-null   int64
#  1   Month        2639 non-null   object
#  2   State        2639 non-null   object
#  3   peak_demand  2639 non-null   float64
#  4   peak_met     2639 non-null   float64
#  5   fy           2639 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 123.8+ KB

# %%
peak_df['Month'] = pd.to_datetime(peak_df['Month'],format="%b-%Y")
peak_df.head()
# Out:
#    ID      Month                     State  peak_demand  peak_met         fy
# 0  44 2020-01-01                Chandigarh        265.0     265.0  2019-2020
# 1  45 2020-01-01                     Delhi       5226.0    5226.0  2019-2020
# 2  46 2020-01-01                   Haryana       7016.0    7016.0  2019-2020
# 3  47 2020-01-01          Himachal Pradesh       1786.0    1786.0  2019-2020
# 4  48 2020-01-01   \nUTs of J&K and Ladakh       3218.0    2574.0  2019-2020

# %%
delhi_df = peak_df[peak_df['State']==' Delhi']
delhi_df.head()
# Out:
#        ID      Month   State  peak_demand  peak_met         fy
# 1      45 2020-01-01   Delhi       5226.0    5226.0  2019-2020
# 44   1674 2020-01-01   Delhi       5226.0    5226.0  2019-2020
# 87      2 2020-02-01   Delhi       4447.0    4447.0  2019-2020
# 130  1631 2020-02-01   Delhi       4447.0    4447.0  2019-2020
# 173  1588 2020-03-01   Delhi       3775.0    3775.0  2019-2020

# %%
delhi2 = delhi_df.groupby('Month').agg({'peak_demand':'mean'})
delhi2.head()
# Out:
#             peak_demand
# Month
# 2020-01-01       5226.0
# 2020-02-01       4447.0
# 2020-03-01       3775.0
# 2020-04-01       3362.0
# 2020-05-01       5464.0

# %%
# !pip install meteostat

# %%
from meteostat import Point, Daily
from datetime import datetime
import pandas as pd

# Define location (Delhi) and time range
delhi = Point(28.6139, 77.2090)
start = datetime(2020, 1, 1)
end = datetime(2024, 6, 30)

# Fetch the daily weather data
data = Daily(delhi, start, end)
df1 = data.fetch()

# Display the data


# You can save it to a CSV file if needed
#df.to_csv('delhi_weather_data.csv')
df1.resample("M").max()
print(df1.head())
delhi2 = delhi2.join(df1['tmax']) # Add suffixes to avoid overlapping column names
delhi2
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2020-01-01  10.8   2.4  20.2   NaN   NaN    NaN   2.3   NaN  1021.9   NaN
# 2020-01-02  13.7   4.6  22.0   NaN   NaN   21.0   2.6   NaN  1021.6   NaN
# 2020-01-03  14.4   7.6  23.0   NaN   NaN   31.0   1.9   NaN  1019.2   NaN
# 2020-01-04  13.6   8.0  23.5   NaN   NaN  325.0   3.1   NaN  1017.9   NaN
# 2020-01-05  14.2   7.0  21.6   NaN   NaN  316.0   4.4   NaN  1018.3   NaN
#             peak_demand  tmax
# Month
# 2020-01-01       5226.0  20.2
# 2020-02-01       4447.0  19.7
# 2020-03-01       3775.0  27.6
# 2020-04-01       3362.0  32.6
# 2020-05-01       5464.0  38.8
# 2020-06-01       6314.0  35.0
# 2020-07-01       6310.0  38.0
# 2020-08-01       5737.0  36.2
# 2020-09-01       6231.0  35.0
# 2020-10-01       4820.0  37.0
# 2020-11-01       3769.0  30.2
# 2020-12-01       4671.0  26.8
# 2021-01-01       5021.0  18.4
# 2021-02-01       4486.0  26.2
# 2021-03-01       3709.0  32.3
# ...

# %%
delhi2.to_csv("delhi_peak.csv")

# %%
import pandas as pd
from prophet import Prophet
import plotly.express as px
from datetime import datetime

# Load and prepare the data
df = pd.read_csv('/content/delhi_peak.csv')  # Replace with your CSV file path
df['Month'] = pd.to_datetime(df['Month'])
df.rename(columns={'Month': 'ds', 'peak_demand': 'y'}, inplace=True)

# Prepare DataFrame for Prophet
# Assuming df contains columns 'ds' (dates), 'y' (peak_demand), and 'tmax' (temperature max)
model = Prophet()
model.add_regressor('tmax')  # Add tmax as an additional regressor

# Fit the model
model.fit(df[['ds', 'y', 'tmax']])

# Create a future DataFrame
future = model.make_future_dataframe(periods=12, freq='MS')  # Forecast for 12 months ahead

# Assuming you have future tmax data for the forecast period
# For demonstration, we'll use historical tmax values; replace this with actual future data
future = future.merge(df[['ds', 'tmax']], on='ds', how='left')
future['tmax'] = future['tmax'].fillna(df['tmax'].mean())  # Fill missing values with historical mean

# Predict future values
forecast = model.predict(future)

# Plot forecast results
fig = px.line(forecast, x='ds', y='yhat', title='Forecasted Peak Demand')
fig.update_traces(mode='lines+markers')
fig.show()

# Print forecast results
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head())
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm3v05s31/k9ex7b1r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpm3v05s31/bpneh3qy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21582', 'data', 'file=/tmp/tmpm3v05s31/k9ex7b1r.json', 'init=/tmp/tmpm3v05s31/bpneh3qy.json', 'output', 'file=/tmp/tmpm3v05s31/prophet_model6s9l7mr9/prophet_model-20240907103045.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:30:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:30:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# ...
# <html>
# ...

# %%
import matplotlib.pyplot as plt

# Plotting the actual vs predicted with confidence interval using matplotlib
plt.figure(figsize=(10, 6))

# Plot actual values
plt.plot(df['ds'], df['y'], label='Actual Energy Peak', color='blue')

# Plot predicted values
plt.plot(forecast['ds'], forecast['yhat'], label='Predicted Energy Peak', color='orange')

# Plot the lower and upper bounds for the forecast
plt.fill_between(forecast['ds'], forecast['yhat_lower'], forecast['yhat_upper'], color='gray', alpha=0.3, label='Confidence Interval')

# Add titles and labels
plt.title('Energy Peak: Actual vs Predicted')
plt.xlabel('Date')
plt.ylabel('Energy Requirement')
plt.legend()

# Show the plot
plt.show()
